# %% [markdown]
# <a href="https://colab.research.google.com/github/sukhadak11/Machine_Learing/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# seaborn
#
# Data visualization library

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# note : seaborn has some built-in datasets

# %%
# to
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# setting theme for plots
sns.set_theme()

# %%
# visualize data
sns.relplot(data=tips, x='total_bill', y='tip',col='time',hue='smoker',style='smoker' , size='size')

# %%
# load iris dataset
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(x='sepal_length', y='petal_length',hue='species',data=iris)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.scatterplot(x='sepal_length', y='petal_width',hue='species',data=iris)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_width'>

# %%
# titaib dataset
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# Count plot

# %%
sns.countplot(x='class',data=titanic)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.countplot(x='survived',data=titanic)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %% [markdown]
# Bar chart

# %%
sns.barplot(x='sex',y='survived',hue='class',data=titanic)
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.distplot(titanic['age'])
# Out:
# <ipython-input-20-0bbae160b97e>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['age'])
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# Correlation
#
# +ve corr
# -ve corr

# %% [markdown]
# Heat map

# %%
correlation = titanic.corr()
# Out:
# <ipython-input-21-20621e451a87>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = titanic.corr()

# %%
# constructing heat map
plt.figure(figsize=(10,10))
sns.heatmap(correlation, cbar=True, square=True, fmt='.1f', annot=True,annot_kws={'size':8}, cmap='Blues')
# Out:
# <Axes: >
